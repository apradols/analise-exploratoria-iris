# %% [markdown]
# <a href="https://colab.research.google.com/github/apradols/analise-exploratoria-iris/blob/main/iris_analise_exploratoria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise exploratória do conjunto de dados 'Iris Species'

# %% [markdown]
# 🎯 Objetivos
#
#   Nesse projeto, foi utilizado o dataset do Kaggle [Iris Species](https://www.kaggle.com/datasets/uciml/iris), para o fim de praticar alguns conceitos de data science.

# %% [markdown]
# 📚 Dicionário dos dados
#
#  * `Id`: Número de itendtificação da iris
#  * `SepalLengthCm`: Comprimento da Sépala em centimetros
#  * `SepalWidthCm`: Largura da Sépala em centimentos
#  * `PetalLengthCm`: Comprimento da Pétala em centrimentos
#  * `PetalWidthCm`: Largura da Pétala em centimentros
#  * `Species`: Espécies

# %% [markdown]
# ⬇ Importando dataset

# %%
import pandas as pd

# %%
dados = pd.read_csv('/content/Iris.csv')

# %% [markdown]
# 🌐 Traduzindo colunas

# %%
mapa = {
    'Id': 'id',
    'SepalLengthCm': 'comprimento_sepala',
    'SepalWidthCm': 'largura_sepala',
    'PetalLengthCm': 'comprimento_petala',
    'PetalWidthCm': 'largura_petala',
    'Species': 'especies'
}
dados = dados.rename(columns=mapa)

# %%
dados.head()
# Out:
#    id  comprimento_sepala  largura_sepala  comprimento_petala  largura_petala  \
# 0   1                 5.1             3.5                 1.4             0.2
# 1   2                 4.9             3.0                 1.4             0.2
# 2   3                 4.7             3.2                 1.3             0.2
# 3   4                 4.6             3.1                 1.5             0.2
# 4   5                 5.0             3.6                 1.4             0.2
#
#       especies
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %% [markdown]
# 📘 Entendo o conjunto de dados

# %%
dados.shape
# Out:
# (150, 6)

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  150 non-null    int64
#  1   comprimento_sepala  150 non-null    float64
#  2   largura_sepala      150 non-null    float64
#  3   comprimento_petala  150 non-null    float64
#  4   largura_petala      150 non-null    float64
#  5   especies            150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
dados.describe()
# Out:
#                id  comprimento_sepala  largura_sepala  comprimento_petala  \
# count  150.000000          150.000000      150.000000          150.000000
# mean    75.500000            5.843333        3.054000            3.758667
# std     43.445368            0.828066        0.433594            1.764420
# min      1.000000            4.300000        2.000000            1.000000
# 25%     38.250000            5.100000        2.800000            1.600000
# 50%     75.500000            5.800000        3.000000            4.350000
# 75%    112.750000            6.400000        3.300000            5.100000
# max    150.000000            7.900000        4.400000            6.900000
#
#        largura_petala
# count      150.000000
# mean         1.198667
# std          0.763161
# min          0.100000
# 25%          0.300000
# 50%          1.300000
# 75%          1.800000
# max          2.500000

# %%
dados.isna().sum()
# Out:
# id                    0
# comprimento_sepala    0
# largura_sepala        0
# comprimento_petala    0
# largura_petala        0
# especies              0
# dtype: int64

# %%
dados.isnull().sum()
# Out:
# id                    0
# comprimento_sepala    0
# largura_sepala        0
# comprimento_petala    0
# largura_petala        0
# especies              0
# dtype: int64

# %%
dados.duplicated().sum()
# Out:
# 0

# %%
dados.corr()
# Out:
# <ipython-input-12-27ee38a39a92>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dados.corr()
#                           id  comprimento_sepala  largura_sepala  \
# id                  1.000000            0.716676       -0.397729
# comprimento_sepala  0.716676            1.000000       -0.109369
# largura_sepala     -0.397729           -0.109369        1.000000
# comprimento_petala  0.882747            0.871754       -0.420516
# largura_petala      0.899759            0.817954       -0.356544
#
#                     comprimento_petala  largura_petala
# id                            0.882747        0.899759
# comprimento_sepala            0.871754        0.817954
# largura_sepala               -0.420516       -0.356544
# comprimento_petala            1.000000        0.962757
# ...

# %% [markdown]
# 📊 Visualizando dados

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax = sns.countplot(x='especies', data=dados)
ax.set_title('Quantidade de cada espécie de iris', fontsize=16)
ax.set_xlabel('Espécies', fontsize=12)
ax.set_ylabel('Quantidade de dados', fontsize=12)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax = sns.scatterplot(data=dados, x='comprimento_petala', y='largura_petala', hue='especies')
ax.set_title('Comparação de comprimento de pétalas e largura das pépalas em relação as espécies', fontsize=15)
ax.set_xlabel('Comprimento de pétalas', fontsize=12)
ax.set_ylabel('Lagura de pétalas', fontsize=12)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax = sns.scatterplot(data=dados, x='comprimento_sepala', y='largura_sepala', hue='especies')
ax.set_title('Comparação de comprimento de sépala e largura das sépala em relação as espécies', fontsize=15)
ax.set_xlabel('Comprimento de sépalas', fontsize=12)
ax.set_ylabel('Lagura de sépalas', fontsize=12)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax = sns.scatterplot(data=dados, x='comprimento_sepala', y='largura_petala', hue='especies')
ax.set_title('Comparação de comprimento de sépala e largura das pétala em relação as espécies', fontsize=15)
ax.set_xlabel('Comprimento de sépalas', fontsize=12)
ax.set_ylabel('Lagura de pétalas', fontsize=12)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax = sns.scatterplot(data=dados, x='comprimento_petala', y='largura_sepala', hue='especies')
ax.set_title('Comparação de comprimento de pétala e largura das sépala em relação as espécies', fontsize=15)
ax.set_xlabel('Comprimento de pétalas', fontsize=12)
ax.set_ylabel('Lagura de sépalas', fontsize=12)
plt.show()

# %% [markdown]
# Boxplot

# %%
def graph(y):
    sns.boxplot(x="especies", y=y, data=dados)

plt.figure(figsize=(12,12))

plt.subplot(221)
graph('largura_sepala')

plt.subplot(222)
graph('largura_petala')

plt.subplot(223)
graph('comprimento_sepala')

plt.subplot(224)
graph('comprimento_petala')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax = sns.heatmap(data=dados.corr(), cmap='rocket', annot=True)
ax.set_title('Gráfico de Correlação')
plt.show()
# Out:
# <ipython-input-69-695390506007>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ax = sns.heatmap(data=dados.corr(), cmap='rocket', annot=True)
